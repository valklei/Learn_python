# %%
0.1 + 0.1 + 0.1
# Out:
# 0.30000000000000004

# %%
0.2

2 -> 10

# %%
7.25

# %%
# 7 => 111

# 7 / 2 = 3 | 1
# 3 / 2 = 1 | 1
# 1 / 2 = 0 | 1


# 0.25 => 01

# 0.25 * 2 = 0.5 | 0
# 0.5 * 2 = 1.0 | 1
# Out:
# 1.0

# %%
111.01

# %%
1.1101

# %%
0 10000001 11010000000000000000000

# %%
# exponenta

2 + 127 = 129 => 10000001

# %%
# 3.25
# 
# 3 => 11
# 0.25 => 01
# 
# 1.101 => 1 => 1 + 127 = 128 => 10000000

# %%
# 0.6 =>

# 0.6 * 2 = 1.2 | 1
# 0.2 * 2 = 0.4 | 0
# 0.4 * 2 = 0.8 | 0
# 0.8 * 2 = 1.6 | 1
# 0.6 * 2 = 1.2 | 1
# 0.2 * 2 = 0.4 | 0
# 0.4 * 2 = 0.8 | 0

# %%
# 1.00110011001100110011001 => -1
# Out:
# 23

# %%
# 7.25

# 0 10000001 11010000000000000000000


# (-1)S x 1.M x 10E

((-1) ** 0) * 1.11010000000000000000000 * (10 ** 2)
# Out:
# 111.01

# %%
#     1 1 1 .  0  1
#     2 1 0 . -1 -2       
left_part = (2 ** 0 * 1) + (2 ** 1 * 1) + (2 ** 2 * 1)
right_part = (2 ** -1 * 0) + (2 ** -2 * 1)

print(left_part)
print(right_part)
# Out:
# 7
# 0.25

# %%
(-1) ** 0
# Out:
# 1

# %%
print("Hello")
# Out:
# Hello

# %%
126 - 64 - 32 -16 - 8 - 4 - 2
# Out:
# 0

# %%
a = 1.5 * 10 ** 3
b = 2.5 * 10 ** 2

print(a)
print(b)

A = 1.5 * 10 ** 3
B = 0.25 * 10 ** 3

print(A)
print(B)

sum_ = 1.5 + 0.25

print(sum_)

res = sum_ * 10 ** 3

print(res)


---------------------------------------------------------------


left_part = (2 ** 0 * 1) + (2 ** 1 * 1) + (2 ** 2 * 1)
right_part = (2 * -1 * 0) + (2 ** -2 * 1)

print(left_part, right_part)

-----------------------------------------------------------------


# 44,102

# 44 => сперва преобразовываем целую часть в двоичное представление
# 44 / 2 = 22 | 0
# 22 / 2 = 11 | 0
# 11 / 2 = 5 | 1
# 5 / 2 = 2 | 1
# 2 / 2 = 1 | 0
# 1 / 2 = 0 | 1 =>
# 101100



# 0.102 => тоже самое делаем с дробной частью. При этом идёт умножение на 2. Если получается
# какаято целая часть - она забирается, как 1 а с остаточной дробной частью операция
# умножения продолжается, пока не получится 0, или пока не пройдёт полный цикл, когда
# первая дробная часть снова повторится (0.102, ... 0.102), или пока не будет заполнена
# вся доступная битовая составляющая (23 бита)
# 0.102 * 2 = 0.204 | 0
# 0.204 * 2 = 0.408 | 0
# 0.408 * 2 = 0.816 | 0
# 0.816 * 2 = 1.632 | 1
# 0.632 * 2 = 1.264 | 1
# 0.264 * 2 = 0.528 | 1
# 0.528 * 2 = 1.056 | 1
# 0.056 * 2 = 0.112 | 0
# 0.112 * 2 = 0.224 | 0
# 0.224 * 2 = 0.448 | 0
# 0.448 * 2 = 0.896 | 0
# 0.896 * 2 = 1.792 | 1
# 0.792 * 2 = 1.584 | 1
# 0.584 * 2 = 1.168 | 1
# 0.168 * 2 = 0.336 | 0
# 0.336 * 2 = 0.672 | 0
# 0.672 * 2 = 1.344 | 0
# 0.344 * 2 = 0.688 | 0
# 0.688 * 2 = 1.376 | 0
# 0.376 * 2 = 0.752 | 0
# 0.752 * 2 = 1.504 | 0
# 0.504 * 2 = 1.008 | 0
# 0.008 * 2 = 0.016 | 0
# 
# 00011110000111000000000


# 101100.00011110000111000000000 # на выходе получается вот такое вот дробное число

1.01100000111100001110000 # сдвигаем точку влево, пока слева не останется единица
# это и есть наша монтиса



# для экспоненты берём цифру, на сколько знаков мы сдвигали точку - 5

# 5 + 127 = 132 => 10000100 -> получается вот такое вот число. Это наша экспонента


# 0 10000100 01100000111100001110000  -> вот так выглядит представление нашего числа 44.102 (примерно)

((-1) ** 0) * 1.01100000111100001110000 * (10 ** 5) # конвертируем число обратно. Для этого подставляем наши
# монтису и экспоненту под формулу преобразования


# 101100 - преобразовываем целую часть

(2 ** 0 * 0) + (2 ** 1 * 0) + (2 ** 2 * 1) + (2 ** 3 * 1) + (2 ** 4 * 0) + (2 ** 5 * 1)


# 0001111 - преобразовываем дробную часть. Тут вполне ожидаема погрешность.

(2 ** -1 * 0) + (2 ** -2 * 0) + (2 ** -3 * 0) + (2 ** -4 * 1) + (2 ** -5 * 1) + (2 ** -6 * 1) + (2 ** -7 * 1)


----------------------------------------------------------------------------------------------------------


# 0.75

# так как целой части нет - преобразовываю дробную

# 0.75 * 2 | 1
# 0.5 * 2 | 1

# получается число 0.11 =>
# смещаю точку, чтобы слева была одна единица 1.1 =>
# высчитываю экспоненту -1 + 127 = 126 => 1111110 =>

# представление числа в машине 0 1111110 10000000000000000000000

#  конвертирую представление на целые и дробные части
((-1) ** 0) * 1.10000000000000000000000 * (10 ** -1)



# беру дробную часть 11000000000000001


(2 ** -1 * 1) + (2 ** -2 * 1) + (2 ** -3 * 0) + (2 ** -4 * 0) + (2 ** -5 * 0) + (2 ** -6 * 0) + \
    (2 ** -7 * 0) + (2 ** -8 * 0) + (2 ** -9 * 0) + (2 ** -10 * 0) + (2 ** -11 * 0) + (2 ** -12 * 0) \
        + (2 ** -13 * 0) + (2 ** -14 * 0) + (2 ** -15 * 0) + (2 ** -16 * 0) + (2 ** -17 * 1)




# 0.75 в представлении будет как 0.11 => 1 . 1
#                                        0  -1

# (−1) ** 0 = 1 - value sign
# 1 + (2 ** -1) = 1.5 - montissa
# 1.5 * (2 ** -1) = 0.75 - result

1.5 * (2 ** -1)


1.010101010101010101 * (2 ** -2)


-------------------------------------------------------------


# 10.0625

# 10
# 10 / 2 = 5 | остаток 0
# 5 / 2 = 2 | остаток 1
# 2 / 2 = 1 | остаток 0
# 1 / 2 = 0 | остаток 1


# 0.625

# 0.0625 * 2 = 0.125 | целая часть 0
# 0.125 * 2 = 0.25   | целая часть 0
# 0.25 * 2 = 0.5     | целая часть 0
# 0.5 * 2 = 1.0      | целая часть 1


# 1010.0001

# 1010.0001 => 1.0100001

# exponent = 3 + 127 = 130 => 10000010


# Знак: 0 (число положительное)
# Экспонента: 10000010
# Мантисса: 01000010000000000000000


# ((-1) ** 0) * 1.0100001 * (10 ** 3) => 1010.0001000000001

# 1010 => (2 ** 0 * 0) + (2 ** 1 * 1) + (2 ** 2 * 0) + (2 ** 3 * 1) => 10


# 0001000000001 => (2 ** -1 * 0) + (2 ** -2 * 0) + (2 ** -3 * 0) + (2 ** -4 * 1) + (2 ** -5 * 0) + 
# (2 ** -6 * 0) + (2 ** -7 * 0) + (2 ** -8 * 0) + (2 ** -9 * 0) + (2 ** -10 * 0) + (2 ** -11 * 0) + 
# (2 ** -12 * 0) + (2 ** -13 * 1) => 0.0626220703125


# 10.0625

# 10 => 1010

# 0.0625 => 0001
# 0.0625 * 2 = 0.125 | 0
# 0.125 * 2 = 0.25 | 0
# 0.25 * 2 = 0.5 | 0
# 0.5 * 2 = 1.0 | 1


# 1010.0001
1.0100001 * 2 ** 3



# 345.6

# 345 => 101011001
# 6 => 10011001100110011010


# 101011001.10011001100110011010

1.0101100110011001100110011010 * (2 ** 8)
